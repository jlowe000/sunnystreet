# %% [markdown]
# Initial Python Notebook Config

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import logging
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.ERROR)

from ads.dataset.factory import DatasetFactory
from ads.dataset.dataset_browser import DatasetBrowser

# %% [markdown]
# Loading Data Into DS

# %%
ds1 = DatasetFactory.open(pd.read_csv("/home/datascience/sunnystreet/data/sunny-street-patients.csv"))
ds2 = DatasetFactory.open("/home/datascience/sunnystreet/data/sunny-street-patient-diagnosis.csv")
ds3 = DatasetFactory.open("/home/datascience/sunnystreet/data/sunny-street-patient-immunisation.csv")
ds4 = DatasetFactory.open("/home/datascience/sunnystreet/data/sunny-street-patient-medicine.csv")
ds5 = DatasetFactory.open("/home/datascience/sunnystreet/data/campfire-shift-measures.csv")
# Out:
# ...
#             <br>
#
#             <div style="width: calc(100% -20px);
#                         border-left: 8px solid #588864;
#                         margin: 10px, 0, 10px, 0px;
#                         padding: 10px">
#
#
#                 <p>Using entire dataset for graphing (1579 rows)</p>
#
#             </div>
#                 <div style="padding: 7px;
#                             border-radius: 4px;
#                             background-color: #d4ecd9;
#                             margin_bottom: 5px;">
#                     <p>Use <code>set_target()</code> to type the dataset for a particular learning task</p>
#                 </div>
# ...
#             <br>
#
#             <div style="width: calc(100% -20px);
#                         border-left: 8px solid #588864;
#                         margin: 10px, 0, 10px, 0px;
#                         padding: 10px">
#
#
#                 <p>Sampling (from 187901 rows) to 10000 rows for graphing</p>
#
#             </div>
# ...

# %%
# These are the top 5 "indicators"
ds1.plot('DIAG_ChronicDiseaseInd','DIAG_MentalHealthInd').show_in_notebook()
ds1.plot('DIAG_ChronicDiseaseInd','DIAG_DepressionInd').show_in_notebook()
ds1.plot('DIAG_ChronicDiseaseInd','DIAG_AnxietyInd').show_in_notebook()
ds1.plot('DIAG_ChronicDiseaseInd','DIAG_DrugAbuseInd').show_in_notebook()

# %%
ds2.show_in_notebook()
# Out:
# Accordion(children=(HTML(value='<h1>Name: sunny-street-patient-diagnosis.csv</h1><h3>Type: ADSDataset</h3><h3>…

# %%
ds3.show_in_notebook()
# Out:
# Accordion(children=(HTML(value='<h1>Name: sunny-street-patient-immunisation.csv</h1><h3>Type: ADSDataset</h3><…

# %%
ds4.show_in_notebook()
# Out:
# Accordion(children=(HTML(value='<h1>Name: sunny-street-patient-medicine.csv</h1><h3>Type: ADSDataset</h3><h3>3…

# %%
ds5.show_in_notebook()
# Out:
# Accordion(children=(HTML(value='<h1>Name: campfire-shift-measures.csv</h1><h3>Type: ADSDataset</h3><h3>191 Row…
